# %%
import os
import subprocess
import numpy as np
import pandas as pd
from ete3 import Tree
import random
import glob
import logging

# Set up logging
logging.basicConfig(level=logging.INFO)
logger = logging.getLogger(__name__)

# Set random seed
random.seed(191919)

# Function to compare trees using TreeCmp
def compare_trees(method, htPath, mtPath, random_trees_path, outPath):
    try:
        # Make comparison folder if it doesn't exist
        compare_folder = os.path.join(outPath, f'compare_{method}')
        if not os.path.isdir(compare_folder):
            os.makedirs(compare_folder)
        
        # Compare host and microbiome tree
        mt_compare_file = os.path.join(compare_folder, 'compare_ht_mt.txt')
        command = f'java -jar "C:/Users/aleja/Downloads/TreeCmp_v1.0-b291/TreeCmp/bin/TreeCmp.jar" -r "{htPath}" -d {method} -i "{mtPath}" -o "{mt_compare_file}" -N'
        logger.info(f'Running command: {command}')
        
        result = subprocess.run(command, shell=True, capture_output=True, text=True)
        logger.info(f'Command output: {result.stdout}')
        logger.error(f'Command error: {result.stderr}')
        
        # Check if the file was created
        if not os.path.isfile(mt_compare_file):
            raise FileNotFoundError(f"Expected output file {mt_compare_file} not found")
        
        # Compare host and random trees
        rt_compare_file = os.path.join(compare_folder, 'compare_ht_random.txt')
        command = f'java -jar "C:/Users/aleja/Downloads/TreeCmp_v1.0-b291/TreeCmp/bin/TreeCmp.jar" -r "{htPath}" -d {method} -i "{random_trees_path}" -o "{rt_compare_file}" -N'
        logger.info(f'Running command: {command}')
        
        result = subprocess.run(command, shell=True, capture_output=True, text=True)
        logger.info(f'Command output: {result.stdout}')
        logger.error(f'Command error: {result.stderr}')
        
        # Check if the file was created
        if not os.path.isfile(rt_compare_file):
            raise FileNotFoundError(f"Expected output file {rt_compare_file} not found")
        
        # Read comparison results
        mtCompare = pd.read_csv(mt_compare_file, sep='\t')
        rtCompare = pd.read_csv(rt_compare_file, sep='\t')
        
        # Print results
        methods = {"rc":'Rooted Robinson-Foulds', "mc":'Rooted Matching Cluster', "ms":'Unrooted Matching Split', "rf":'Unrooted Robinson-Foulds'}
        logger.info(f' --- METHOD: {methods[method]} --- ')
        logger.info(f"Host-Microbe Score:   {mtCompare.iloc[0,1]}")
        max_stochastic_metric = max(rtCompare.iloc[:,1])
        logger.info(f"Max Stochastic Metric: {max_stochastic_metric}")
        normalized_score = mtCompare.iloc[0,1] / max_stochastic_metric
        logger.info(f'Normalized Score: {normalized_score}')
        congruent_trees_count = len(rtCompare[rtCompare.iloc[:,1] <= mtCompare.iloc[0,1]])
        logger.info(f'Random Trees with Equivalent or More Congruent Score: {congruent_trees_count}')
        total_trees = len(rtCompare)
        logger.info(f'Total Trees: {total_trees}')
        p_value = congruent_trees_count / total_trees
        logger.info(f'P-Value: {p_value}\n')
        
    except Exception as e:
        logger.error(f'Error comparing trees with method {method}: {e}')

# Main script
def main():
    try:
        # User-defined paths
        outPath = r'C:/Users/aleja/OneDrive - Karolinska Institutet/Documentos/JOBS/Liquenes/Lichens_project/Sticta/co-divergence/Reviewed'
        htPath = os.path.join(outPath, 'ht.newick')
        mtPath = os.path.join(outPath, 'mt.newick')
        random_trees_path = os.path.join(outPath, 'random_trees.newick')
        
        # Import trees
        htIn = Tree(htPath)
        mtIn = Tree(mtPath)
        
        # Check if trees have the same number of leaves
        if len(htIn) != len(mtIn):
            raise ValueError('Host and Microbiome Tree Have Different Numbers of Nodes!')
        
        # List to store host leaf names
        htLeafs = [leaf.name for leaf in mtIn]
        
        # Generate random trees
        rtPath = os.path.join(outPath, 'random_trees')
        if not os.path.isdir(rtPath):
            os.makedirs(rtPath)
        
        # Define number of random trees
        numRandom = 10000
        
        for curRandom in np.arange(numRandom):
            t = Tree()
            random.shuffle(htLeafs)
            t.populate(len(htIn), names_library=htLeafs)
            t.write(outfile=os.path.join(rtPath, f'tree_{curRandom}.newick'))
        
        # Concatenate random trees into a single file
        random_tree_files = glob.glob(os.path.join(rtPath, '*'))
        with open(random_trees_path, 'w') as outfile:
            for file in random_tree_files:
                with open(file, 'r') as infile:
                    outfile.write(infile.read())
        
        # Perform comparisons for each method
        for method in ["rc", "mc", "rf", "ms"]:
            compare_trees(method, htPath, mtPath, random_trees_path, outPath)
    
    except Exception as e:
        logger.error(f'Error in main script: {e}')

if __name__ == "__main__":
    main()
# Out:
# INFO:__main__:Running command: java -jar "C:/Users/aleja/Downloads/TreeCmp_v1.0-b291/TreeCmp/bin/TreeCmp.jar" -r "C:/Users/aleja/OneDrive - Karolinska Institutet/Documentos/JOBS/Liquenes/Lichens_project/Sticta/co-divergence/Reviewed\ht.newick" -d rc -i "C:/Users/aleja/OneDrive - Karolinska Institutet/Documentos/JOBS/Liquenes/Lichens_project/Sticta/co-divergence/Reviewed\mt.newick" -o "C:/Users/aleja/OneDrive - Karolinska Institutet/Documentos/JOBS/Liquenes/Lichens_project/Sticta/co-divergence/Reviewed\compare_rc\compare_ht_mt.txt" -N
# INFO:__main__:Command output: TreeCmp version 1.0-b291
#
# Active options:
# Type of the analysis:  one-to-all comparison mode (-r)
# Metrics:
#   1. R-F_Cluster (rc)
# Input file: C:/Users/aleja/OneDrive - Karolinska Institutet/Documentos/JOBS/Liquenes/Lichens_project/Sticta/co-divergence/Reviewed\mt.newick
# Output file: C:/Users/aleja/OneDrive - Karolinska Institutet/Documentos/JOBS/Liquenes/Lichens_project/Sticta/co-divergence/Reviewed\compare_rc\compare_ht_mt.txt
# Additional options:
# N - Report normalized distances.
# -----
# 2024-06-22 13:33:01: Start of reading random statistics.
# 2024-06-22 13:33:01: End of reading random statistics.
# 2024-06-22 13:33:01: Start of scanning input file: C:/Users/aleja/OneDrive - Karolinska Institutet/Documentos/JOBS/Liquenes/Lichens_project/Sticta/co-divergence/Reviewed\mt.newick
# 2024-06-22 13:33:01: End of scanning input file: C:/Users/aleja/OneDrive - Karolinska Institutet/Documentos/JOBS/Liquenes/Lichens_project/Sticta/co-divergence/Reviewed\mt.newick
# 2024-06-22 13:33:01: 1 valid trees found in file: C:/Users/aleja/OneDrive - Karolinska Institutet/Documentos/JOBS/Liquenes/Lichens_project/Sticta/co-divergence/Reviewed\mt.newick
# 2024-06-22 13:33:01: Start of calculation...please wait...
# 2024-06-22 13:33:01: 0.00% completed...
# 2024-06-22 13:33:01: 100.00% completed.
# 2024-06-22 13:33:01: End of calculation.
# 2024-06-22 13:33:01: Total calculation time: 14 ms.
#
# ERROR:__main__:Command error:
# INFO:__main__:Running command: java -jar "C:/Users/aleja/Downloads/TreeCmp_v1.0-b291/TreeCmp/bin/TreeCmp.jar" -r "C:/Users/aleja/OneDrive - Karolinska Institutet/Documentos/JOBS/Liquenes/Lichens_project/Sticta/co-divergence/Reviewed\ht.newick" -d rc -i "C:/Users/aleja/OneDrive - Karolinska Institutet/Documentos/JOBS/Liquenes/Lichens_project/Sticta/co-divergence/Reviewed\random_trees.newick" -o "C:/Users/aleja/OneDrive - Karolinska Institutet/Documentos/JOBS/Liquenes/Lichens_project/Sticta/co-divergence/Reviewed\compare_rc\compare_ht_random.txt" -N
# INFO:__main__:Command output: TreeCmp version 1.0-b291
#
# Active options:
# Type of the analysis:  one-to-all comparison mode (-r)
# Metrics:
#   1. R-F_Cluster (rc)
# Input file: C:/Users/aleja/OneDrive - Karolinska Institutet/Documentos/JOBS/Liquenes/Lichens_project/Sticta/co-divergence/Reviewed\random_trees.newick
# Output file: C:/Users/aleja/OneDrive - Karolinska Institutet/Documentos/JOBS/Liquenes/Lichens_project/Sticta/co-divergence/Reviewed\compare_rc\compare_ht_random.txt
# Additional options:
# N - Report normalized distances.
# -----
# 2024-06-22 13:33:02: Start of reading random statistics.
# 2024-06-22 13:33:02: End of reading random statistics.
# 2024-06-22 13:33:02: Start of scanning input file: C:/Users/aleja/OneDrive - Karolinska Institutet/Documentos/JOBS/Liquenes/Lichens_project/Sticta/co-divergence/Reviewed\random_trees.newick
# 2024-06-22 13:33:02: End of scanning input file: C:/Users/aleja/OneDrive - Karolinska Institutet/Documentos/JOBS/Liquenes/Lichens_project/Sticta/co-divergence/Reviewed\random_trees.newick
# 2024-06-22 13:33:02: 10000 valid trees found in file: C:/Users/aleja/OneDrive - Karolinska Institutet/Documentos/JOBS/Liquenes/Lichens_project/Sticta/co-divergence/Reviewed\random_trees.newick
# 2024-06-22 13:33:02: Start of calculation...please wait...
# 2024-06-22 13:33:02: 0.00% completed...
# 2024-06-22 13:33:02: 5.00% completed...
# 2024-06-22 13:33:02: 10.00% completed...
# 2024-06-22 13:33:02: 15.00% completed...
# 2024-06-22 13:33:02: 20.00% completed...
# 2024-06-22 13:33:02: 25.00% completed...
# 2024-06-22 13:33:02: 30.00% completed...
# 2024-06-22 13:33:02: 35.00% completed...
# 2024-06-22 13:33:02: 40.00% completed...
# 2024-06-22 13:33:02: 45.00% completed...
# 2024-06-22 13:33:02: 50.00% completed...
# 2024-06-22 13:33:02: 55.00% completed...
# 2024-06-22 13:33:02: 60.00% completed...
# 2024-06-22 13:33:02: 65.00% completed...
# 2024-06-22 13:33:02: 70.00% completed...
# 2024-06-22 13:33:02: 75.00% completed...
# 2024-06-22 13:33:02: 80.00% completed...
# 2024-06-22 13:33:02: 85.00% completed...
# 2024-06-22 13:33:03: 90.00% completed...
# 2024-06-22 13:33:03: 95.00% completed...
# 2024-06-22 13:33:03: 100.00% completed.
# 2024-06-22 13:33:03: End of calculation.
# 2024-06-22 13:33:03: Total calculation time: 494 ms.
#
# ERROR:__main__:Command error:
# INFO:__main__: --- METHOD: Rooted Robinson-Foulds ---
# INFO:__main__:Host-Microbe Score:   3.5
# INFO:__main__:Max Stochastic Metric: 4.5
# INFO:__main__:Normalized Score: 0.7777777777777778
# INFO:__main__:Random Trees with Equivalent or More Congruent Score: 3090
# INFO:__main__:Total Trees: 10000
# INFO:__main__:P-Value: 0.309
#
# INFO:__main__:Running command: java -jar "C:/Users/aleja/Downloads/TreeCmp_v1.0-b291/TreeCmp/bin/TreeCmp.jar" -r "C:/Users/aleja/OneDrive - Karolinska Institutet/Documentos/JOBS/Liquenes/Lichens_project/Sticta/co-divergence/Reviewed\ht.newick" -d mc -i "C:/Users/aleja/OneDrive - Karolinska Institutet/Documentos/JOBS/Liquenes/Lichens_project/Sticta/co-divergence/Reviewed\mt.newick" -o "C:/Users/aleja/OneDrive - Karolinska Institutet/Documentos/JOBS/Liquenes/Lichens_project/Sticta/co-divergence/Reviewed\compare_mc\compare_ht_mt.txt" -N
# INFO:__main__:Command output: TreeCmp version 1.0-b291
#
# Active options:
# Type of the analysis:  one-to-all comparison mode (-r)
# Metrics:
#   1. MatchingCluster (mc)
# Input file: C:/Users/aleja/OneDrive - Karolinska Institutet/Documentos/JOBS/Liquenes/Lichens_project/Sticta/co-divergence/Reviewed\mt.newick
# Output file: C:/Users/aleja/OneDrive - Karolinska Institutet/Documentos/JOBS/Liquenes/Lichens_project/Sticta/co-divergence/Reviewed\compare_mc\compare_ht_mt.txt
# Additional options:
# N - Report normalized distances.
# -----
# 2024-06-22 13:33:03: Start of reading random statistics.
# 2024-06-22 13:33:03: End of reading random statistics.
# 2024-06-22 13:33:03: Start of scanning input file: C:/Users/aleja/OneDrive - Karolinska Institutet/Documentos/JOBS/Liquenes/Lichens_project/Sticta/co-divergence/Reviewed\mt.newick
# 2024-06-22 13:33:03: End of scanning input file: C:/Users/aleja/OneDrive - Karolinska Institutet/Documentos/JOBS/Liquenes/Lichens_project/Sticta/co-divergence/Reviewed\mt.newick
# 2024-06-22 13:33:03: 1 valid trees found in file: C:/Users/aleja/OneDrive - Karolinska Institutet/Documentos/JOBS/Liquenes/Lichens_project/Sticta/co-divergence/Reviewed\mt.newick
# 2024-06-22 13:33:03: Start of calculation...please wait...
# 2024-06-22 13:33:03: 0.00% completed...
# 2024-06-22 13:33:03: 100.00% completed.
# 2024-06-22 13:33:03: End of calculation.
# 2024-06-22 13:33:03: Total calculation time: 16 ms.
#
# ERROR:__main__:Command error:
# INFO:__main__:Running command: java -jar "C:/Users/aleja/Downloads/TreeCmp_v1.0-b291/TreeCmp/bin/TreeCmp.jar" -r "C:/Users/aleja/OneDrive - Karolinska Institutet/Documentos/JOBS/Liquenes/Lichens_project/Sticta/co-divergence/Reviewed\ht.newick" -d mc -i "C:/Users/aleja/OneDrive - Karolinska Institutet/Documentos/JOBS/Liquenes/Lichens_project/Sticta/co-divergence/Reviewed\random_trees.newick" -o "C:/Users/aleja/OneDrive - Karolinska Institutet/Documentos/JOBS/Liquenes/Lichens_project/Sticta/co-divergence/Reviewed\compare_mc\compare_ht_random.txt" -N
# INFO:__main__:Command output: TreeCmp version 1.0-b291
#
# Active options:
# Type of the analysis:  one-to-all comparison mode (-r)
# Metrics:
#   1. MatchingCluster (mc)
# Input file: C:/Users/aleja/OneDrive - Karolinska Institutet/Documentos/JOBS/Liquenes/Lichens_project/Sticta/co-divergence/Reviewed\random_trees.newick
# Output file: C:/Users/aleja/OneDrive - Karolinska Institutet/Documentos/JOBS/Liquenes/Lichens_project/Sticta/co-divergence/Reviewed\compare_mc\compare_ht_random.txt
# Additional options:
# N - Report normalized distances.
# -----
# 2024-06-22 13:33:03: Start of reading random statistics.
# 2024-06-22 13:33:03: End of reading random statistics.
# 2024-06-22 13:33:03: Start of scanning input file: C:/Users/aleja/OneDrive - Karolinska Institutet/Documentos/JOBS/Liquenes/Lichens_project/Sticta/co-divergence/Reviewed\random_trees.newick
# 2024-06-22 13:33:04: End of scanning input file: C:/Users/aleja/OneDrive - Karolinska Institutet/Documentos/JOBS/Liquenes/Lichens_project/Sticta/co-divergence/Reviewed\random_trees.newick
# 2024-06-22 13:33:04: 10000 valid trees found in file: C:/Users/aleja/OneDrive - Karolinska Institutet/Documentos/JOBS/Liquenes/Lichens_project/Sticta/co-divergence/Reviewed\random_trees.newick
# 2024-06-22 13:33:04: Start of calculation...please wait...
# 2024-06-22 13:33:04: 0.00% completed...
# 2024-06-22 13:33:04: 5.00% completed...
# 2024-06-22 13:33:04: 10.00% completed...
# 2024-06-22 13:33:04: 15.00% completed...
# 2024-06-22 13:33:04: 20.00% completed...
# 2024-06-22 13:33:04: 25.00% completed...
# 2024-06-22 13:33:04: 30.00% completed...
# 2024-06-22 13:33:04: 35.00% completed...
# 2024-06-22 13:33:04: 40.00% completed...
# 2024-06-22 13:33:04: 45.00% completed...
# 2024-06-22 13:33:04: 50.00% completed...
# 2024-06-22 13:33:04: 55.00% completed...
# 2024-06-22 13:33:04: 60.00% completed...
# 2024-06-22 13:33:04: 65.00% completed...
# 2024-06-22 13:33:04: 70.00% completed...
# 2024-06-22 13:33:04: 75.00% completed...
# 2024-06-22 13:33:04: 80.00% completed...
# 2024-06-22 13:33:04: 85.00% completed...
# 2024-06-22 13:33:04: 90.00% completed...
# 2024-06-22 13:33:04: 95.00% completed...
# 2024-06-22 13:33:04: 100.00% completed.
# 2024-06-22 13:33:04: End of calculation.
# 2024-06-22 13:33:04: Total calculation time: 774 ms.
#
# ERROR:__main__:Command error:
# INFO:__main__: --- METHOD: Rooted Matching Cluster ---
# INFO:__main__:Host-Microbe Score:   9.0
# INFO:__main__:Max Stochastic Metric: 16.0
# INFO:__main__:Normalized Score: 0.5625
# INFO:__main__:Random Trees with Equivalent or More Congruent Score: 1805
# INFO:__main__:Total Trees: 10000
# INFO:__main__:P-Value: 0.1805
#
# INFO:__main__:Running command: java -jar "C:/Users/aleja/Downloads/TreeCmp_v1.0-b291/TreeCmp/bin/TreeCmp.jar" -r "C:/Users/aleja/OneDrive - Karolinska Institutet/Documentos/JOBS/Liquenes/Lichens_project/Sticta/co-divergence/Reviewed\ht.newick" -d rf -i "C:/Users/aleja/OneDrive - Karolinska Institutet/Documentos/JOBS/Liquenes/Lichens_project/Sticta/co-divergence/Reviewed\mt.newick" -o "C:/Users/aleja/OneDrive - Karolinska Institutet/Documentos/JOBS/Liquenes/Lichens_project/Sticta/co-divergence/Reviewed\compare_rf\compare_ht_mt.txt" -N
# INFO:__main__:Command output: TreeCmp version 1.0-b291
#
# Active options:
# Type of the analysis:  one-to-all comparison mode (-r)
# Metrics:
#   1. R-F (rf)
# Input file: C:/Users/aleja/OneDrive - Karolinska Institutet/Documentos/JOBS/Liquenes/Lichens_project/Sticta/co-divergence/Reviewed\mt.newick
# Output file: C:/Users/aleja/OneDrive - Karolinska Institutet/Documentos/JOBS/Liquenes/Lichens_project/Sticta/co-divergence/Reviewed\compare_rf\compare_ht_mt.txt
# Additional options:
# N - Report normalized distances.
# -----
# 2024-06-22 13:33:05: Start of reading random statistics.
# 2024-06-22 13:33:05: End of reading random statistics.
# 2024-06-22 13:33:05: Start of scanning input file: C:/Users/aleja/OneDrive - Karolinska Institutet/Documentos/JOBS/Liquenes/Lichens_project/Sticta/co-divergence/Reviewed\mt.newick
# 2024-06-22 13:33:05: End of scanning input file: C:/Users/aleja/OneDrive - Karolinska Institutet/Documentos/JOBS/Liquenes/Lichens_project/Sticta/co-divergence/Reviewed\mt.newick
# 2024-06-22 13:33:05: 1 valid trees found in file: C:/Users/aleja/OneDrive - Karolinska Institutet/Documentos/JOBS/Liquenes/Lichens_project/Sticta/co-divergence/Reviewed\mt.newick
# 2024-06-22 13:33:05: Start of calculation...please wait...
# 2024-06-22 13:33:05: 0.00% completed...
# 2024-06-22 13:33:05: 100.00% completed.
# 2024-06-22 13:33:05: End of calculation.
# 2024-06-22 13:33:05: Total calculation time: 25 ms.
#
# ERROR:__main__:Command error:
# INFO:__main__:Running command: java -jar "C:/Users/aleja/Downloads/TreeCmp_v1.0-b291/TreeCmp/bin/TreeCmp.jar" -r "C:/Users/aleja/OneDrive - Karolinska Institutet/Documentos/JOBS/Liquenes/Lichens_project/Sticta/co-divergence/Reviewed\ht.newick" -d rf -i "C:/Users/aleja/OneDrive - Karolinska Institutet/Documentos/JOBS/Liquenes/Lichens_project/Sticta/co-divergence/Reviewed\random_trees.newick" -o "C:/Users/aleja/OneDrive - Karolinska Institutet/Documentos/JOBS/Liquenes/Lichens_project/Sticta/co-divergence/Reviewed\compare_rf\compare_ht_random.txt" -N
# INFO:__main__:Command output: TreeCmp version 1.0-b291
#
# Active options:
# Type of the analysis:  one-to-all comparison mode (-r)
# Metrics:
#   1. R-F (rf)
# Input file: C:/Users/aleja/OneDrive - Karolinska Institutet/Documentos/JOBS/Liquenes/Lichens_project/Sticta/co-divergence/Reviewed\random_trees.newick
# Output file: C:/Users/aleja/OneDrive - Karolinska Institutet/Documentos/JOBS/Liquenes/Lichens_project/Sticta/co-divergence/Reviewed\compare_rf\compare_ht_random.txt
# Additional options:
# N - Report normalized distances.
# -----
# 2024-06-22 13:33:05: Start of reading random statistics.
# 2024-06-22 13:33:05: End of reading random statistics.
# 2024-06-22 13:33:05: Start of scanning input file: C:/Users/aleja/OneDrive - Karolinska Institutet/Documentos/JOBS/Liquenes/Lichens_project/Sticta/co-divergence/Reviewed\random_trees.newick
# 2024-06-22 13:33:05: End of scanning input file: C:/Users/aleja/OneDrive - Karolinska Institutet/Documentos/JOBS/Liquenes/Lichens_project/Sticta/co-divergence/Reviewed\random_trees.newick
# 2024-06-22 13:33:05: 10000 valid trees found in file: C:/Users/aleja/OneDrive - Karolinska Institutet/Documentos/JOBS/Liquenes/Lichens_project/Sticta/co-divergence/Reviewed\random_trees.newick
# 2024-06-22 13:33:05: Start of calculation...please wait...
# 2024-06-22 13:33:05: 0.00% completed...
# 2024-06-22 13:33:05: 5.00% completed...
# 2024-06-22 13:33:06: 10.00% completed...
# 2024-06-22 13:33:06: 15.00% completed...
# 2024-06-22 13:33:06: 20.00% completed...
# 2024-06-22 13:33:06: 25.00% completed...
# 2024-06-22 13:33:06: 30.00% completed...
# 2024-06-22 13:33:06: 35.00% completed...
# 2024-06-22 13:33:06: 40.00% completed...
# 2024-06-22 13:33:06: 45.00% completed...
# 2024-06-22 13:33:06: 50.00% completed...
# 2024-06-22 13:33:06: 55.00% completed...
# 2024-06-22 13:33:06: 60.00% completed...
# 2024-06-22 13:33:06: 65.00% completed...
# 2024-06-22 13:33:06: 70.00% completed...
# 2024-06-22 13:33:06: 75.00% completed...
# 2024-06-22 13:33:06: 80.00% completed...
# 2024-06-22 13:33:06: 85.00% completed...
# 2024-06-22 13:33:06: 90.00% completed...
# 2024-06-22 13:33:06: 95.00% completed...
# 2024-06-22 13:33:06: 100.00% completed.
# 2024-06-22 13:33:06: End of calculation.
# 2024-06-22 13:33:06: Total calculation time: 617 ms.
#
# ERROR:__main__:Command error:
# INFO:__main__: --- METHOD: Unrooted Robinson-Foulds ---
# INFO:__main__:Host-Microbe Score:   3.0
# INFO:__main__:Max Stochastic Metric: 4.0
# INFO:__main__:Normalized Score: 0.75
# INFO:__main__:Random Trees with Equivalent or More Congruent Score: 3245
# INFO:__main__:Total Trees: 10000
# INFO:__main__:P-Value: 0.3245
#
# INFO:__main__:Running command: java -jar "C:/Users/aleja/Downloads/TreeCmp_v1.0-b291/TreeCmp/bin/TreeCmp.jar" -r "C:/Users/aleja/OneDrive - Karolinska Institutet/Documentos/JOBS/Liquenes/Lichens_project/Sticta/co-divergence/Reviewed\ht.newick" -d ms -i "C:/Users/aleja/OneDrive - Karolinska Institutet/Documentos/JOBS/Liquenes/Lichens_project/Sticta/co-divergence/Reviewed\mt.newick" -o "C:/Users/aleja/OneDrive - Karolinska Institutet/Documentos/JOBS/Liquenes/Lichens_project/Sticta/co-divergence/Reviewed\compare_ms\compare_ht_mt.txt" -N
# INFO:__main__:Command output: TreeCmp version 1.0-b291
#
# Active options:
# Type of the analysis:  one-to-all comparison mode (-r)
# Metrics:
#   1. MatchingSplit (ms)
# Input file: C:/Users/aleja/OneDrive - Karolinska Institutet/Documentos/JOBS/Liquenes/Lichens_project/Sticta/co-divergence/Reviewed\mt.newick
# Output file: C:/Users/aleja/OneDrive - Karolinska Institutet/Documentos/JOBS/Liquenes/Lichens_project/Sticta/co-divergence/Reviewed\compare_ms\compare_ht_mt.txt
# Additional options:
# N - Report normalized distances.
# -----
# 2024-06-22 13:33:06: Start of reading random statistics.
# 2024-06-22 13:33:06: End of reading random statistics.
# 2024-06-22 13:33:06: Start of scanning input file: C:/Users/aleja/OneDrive - Karolinska Institutet/Documentos/JOBS/Liquenes/Lichens_project/Sticta/co-divergence/Reviewed\mt.newick
# 2024-06-22 13:33:06: End of scanning input file: C:/Users/aleja/OneDrive - Karolinska Institutet/Documentos/JOBS/Liquenes/Lichens_project/Sticta/co-divergence/Reviewed\mt.newick
# 2024-06-22 13:33:06: 1 valid trees found in file: C:/Users/aleja/OneDrive - Karolinska Institutet/Documentos/JOBS/Liquenes/Lichens_project/Sticta/co-divergence/Reviewed\mt.newick
# 2024-06-22 13:33:06: Start of calculation...please wait...
# 2024-06-22 13:33:06: 0.00% completed...
# 2024-06-22 13:33:06: 100.00% completed.
# 2024-06-22 13:33:06: End of calculation.
# 2024-06-22 13:33:06: Total calculation time: 33 ms.
#
# ERROR:__main__:Command error:
# INFO:__main__:Running command: java -jar "C:/Users/aleja/Downloads/TreeCmp_v1.0-b291/TreeCmp/bin/TreeCmp.jar" -r "C:/Users/aleja/OneDrive - Karolinska Institutet/Documentos/JOBS/Liquenes/Lichens_project/Sticta/co-divergence/Reviewed\ht.newick" -d ms -i "C:/Users/aleja/OneDrive - Karolinska Institutet/Documentos/JOBS/Liquenes/Lichens_project/Sticta/co-divergence/Reviewed\random_trees.newick" -o "C:/Users/aleja/OneDrive - Karolinska Institutet/Documentos/JOBS/Liquenes/Lichens_project/Sticta/co-divergence/Reviewed\compare_ms\compare_ht_random.txt" -N
# INFO:__main__:Command output: TreeCmp version 1.0-b291
#
# Active options:
# Type of the analysis:  one-to-all comparison mode (-r)
# Metrics:
#   1. MatchingSplit (ms)
# Input file: C:/Users/aleja/OneDrive - Karolinska Institutet/Documentos/JOBS/Liquenes/Lichens_project/Sticta/co-divergence/Reviewed\random_trees.newick
# Output file: C:/Users/aleja/OneDrive - Karolinska Institutet/Documentos/JOBS/Liquenes/Lichens_project/Sticta/co-divergence/Reviewed\compare_ms\compare_ht_random.txt
# Additional options:
# N - Report normalized distances.
# -----
# 2024-06-22 13:33:07: Start of reading random statistics.
# 2024-06-22 13:33:07: End of reading random statistics.
# 2024-06-22 13:33:07: Start of scanning input file: C:/Users/aleja/OneDrive - Karolinska Institutet/Documentos/JOBS/Liquenes/Lichens_project/Sticta/co-divergence/Reviewed\random_trees.newick
# 2024-06-22 13:33:07: End of scanning input file: C:/Users/aleja/OneDrive - Karolinska Institutet/Documentos/JOBS/Liquenes/Lichens_project/Sticta/co-divergence/Reviewed\random_trees.newick
# 2024-06-22 13:33:07: 10000 valid trees found in file: C:/Users/aleja/OneDrive - Karolinska Institutet/Documentos/JOBS/Liquenes/Lichens_project/Sticta/co-divergence/Reviewed\random_trees.newick
# 2024-06-22 13:33:07: Start of calculation...please wait...
# 2024-06-22 13:33:07: 0.00% completed...
# 2024-06-22 13:33:07: 5.00% completed...
# 2024-06-22 13:33:07: 10.00% completed...
# 2024-06-22 13:33:07: 15.00% completed...
# 2024-06-22 13:33:07: 20.00% completed...
# 2024-06-22 13:33:07: 25.00% completed...
# 2024-06-22 13:33:08: 30.00% completed...
# 2024-06-22 13:33:08: 35.00% completed...
# 2024-06-22 13:33:08: 40.00% completed...
# 2024-06-22 13:33:08: 45.00% completed...
# 2024-06-22 13:33:08: 50.00% completed...
# 2024-06-22 13:33:08: 55.00% completed...
# 2024-06-22 13:33:08: 60.00% completed...
# 2024-06-22 13:33:08: 65.00% completed...
# 2024-06-22 13:33:08: 70.00% completed...
# 2024-06-22 13:33:08: 75.00% completed...
# 2024-06-22 13:33:08: 80.00% completed...
# 2024-06-22 13:33:08: 85.00% completed...
# 2024-06-22 13:33:08: 90.00% completed...
# 2024-06-22 13:33:08: 95.00% completed...
# 2024-06-22 13:33:08: 100.00% completed.
# 2024-06-22 13:33:08: End of calculation.
# 2024-06-22 13:33:08: Total calculation time: 779 ms.
#
# ERROR:__main__:Command error:
# INFO:__main__: --- METHOD: Unrooted Matching Split ---
# INFO:__main__:Host-Microbe Score:   6.0
# INFO:__main__:Max Stochastic Metric: 10.0
# INFO:__main__:Normalized Score: 0.6
# INFO:__main__:Random Trees with Equivalent or More Congruent Score: 2899
# INFO:__main__:Total Trees: 10000
# INFO:__main__:P-Value: 0.2899
